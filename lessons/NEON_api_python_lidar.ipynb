# %% [markdown]
# Let's download some lidar data using the [NEON Data Portal API](http://data.neonscience.org/data-api)
#
# First we are going to import `requests` and `json` libraries

# %%
import requests
import json
import os
import time

SITECODE = "SRER" #the site code for Santa Rita Experimental Range
PRODUCTCODE = "DP1.30003.001" #the product code for Discrete Return lidar
SERVER = "http://data.neonscience.org/api/v0/" #the current server address

# %% [markdown]
# We want to track how big the files sizes are - in case there is a breakdown in the transfer.
#
# Here is a simple way to track the file size using some definitions:

# %%
def convert_bytes(num):
    """
    this function will convert bytes to MB.... GB... etc
    """
    for x in ['bytes', 'KB', 'MB', 'GB', 'TB']:
        if num < 1024.0:
            return "%3.1f %s" % (num, x)
        num /= 1024.0

def file_size(file_path):
    """
    this function will return the file size
    """
    if os.path.isfile(file_path):
        file_info = os.stat(file_path)
        return convert_bytes(file_info.st_size)

# %% [markdown]
# We query the server for the site location:

# %%
site_response = requests.get(SERVER + 'sites/' + SITECODE)

# %% [markdown]
# Next, we create a JSON blob for viewing the data at this site:

# %%
site_response_json = site_response.json()
print(json.dumps(site_response_json, indent=2)) #using json.dumps for formatting
# Out:
# {
#   "data": {
#     "siteDescription": "Santa Rita Experimental Range",
#     "siteLongitude": -110.83549,
#     "siteType": "CORE",
#     "stateName": "Arizona",
#     "stateCode": "AZ",
#     "siteLatitude": 31.91068,
#     "domainName": "Desert Southwest",
#     "domainCode": "D14",
#     "siteCode": "SRER",
#     "dataProducts": [
#       {
#         "dataProductCode": "DP1.10066.001",
#         "dataProductTitle": "Root sampling (Megapit)",
#         "availableMonths": [
#           "2013-11"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.10066.001/SRER/2013-11"
#         ]
#       },
#       {
#         "dataProductCode": "DP1.10023.001",
#         "dataProductTitle": "Herbaceous clip harvest",
#         "availableMonths": [
#           "2016-04",
#           "2016-08",
#           "2017-04",
#           "2017-05",
#           "2017-06",
#           "2017-08",
#           "2017-09"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.10023.001/SRER/2016-04",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10023.001/SRER/2016-08",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10023.001/SRER/2017-04",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10023.001/SRER/2017-05",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10023.001/SRER/2017-06",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10023.001/SRER/2017-08",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10023.001/SRER/2017-09"
#         ]
#       },
#       {
#         "dataProductCode": "DP1.30006.001",
#         "dataProductTitle": "Spectrometer orthorectified surface directional reflectance - flightline",
#         "availableMonths": [
#           "2017-08"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.30006.001/SRER/2017-08"
#         ]
#       },
#       {
#         "dataProductCode": "DP2.30020.001",
#         "dataProductTitle": "Canopy xanthophyll cycle - flightline",
#         "availableMonths": [
#           "2017-08"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP2.30020.001/SRER/2017-08"
#         ]
#       },
#       {
#         "dataProductCode": "DP1.10058.001",
#         "dataProductTitle": "Plant presence and percent cover",
#         "availableMonths": [
#           "2016-01",
#           "2016-04",
#           "2016-08",
#           "2017-03",
#           "2017-04",
#           "2017-05",
#           "2017-08",
#           "2017-09"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.10058.001/SRER/2016-01",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10058.001/SRER/2016-04",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10058.001/SRER/2016-08",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10058.001/SRER/2017-03",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10058.001/SRER/2017-04",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10058.001/SRER/2017-05",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10058.001/SRER/2017-08",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10058.001/SRER/2017-09"
#         ]
#       },
#       {
#         "dataProductCode": "DP1.00096.001",
#         "dataProductTitle": "Soil physical properties (Megapit)",
#         "availableMonths": [
#           "2013-11"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.00096.001/SRER/2013-11"
#         ]
#       },
#       {
#         "dataProductCode": "DP1

#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP3.30015.001/SRER/2017-08"
#         ]
#       },
#       {
#         "dataProductCode": "DP1.10043.001",
#         "dataProductTitle": "Mosquitoes sampled from CO2 traps",
#         "availableMonths": [
#           "2016-04",
#           "2016-05",
#           "2016-06",
#           "2016-07",
#           "2016-08",
#           "2016-09",
#           "2016-10",
#           "2017-03",
#           "2017-04",
#           "2017-05",
#           "2017-06",
#           "2017-07",
#           "2017-08",
#           "2017-09",
#           "2017-10",
#           "2017-11",
#           "2017-12",
#           "2018-01",
#           "2018-02",
#           "2018-03"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2016-04",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2016-05",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2016-06",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2016-07",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2016-08",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2016-09",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2016-10",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-03",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-04",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-05",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-06",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-07",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-08",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-09",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-10",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-11",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2017-12",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2018-01",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2018-02",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10043.001/SRER/2018-03"
#         ]
#       },
#       {
#         "dataProductCode": "DP1.00005.001",
#         "dataProductTitle": "IR biological temperature",
#         "availableMonths": [
#           "2017-02",
#           "2017-03",
#           "2017-04",
#           "2017-05",
#           "2017-07",
#           "2017-08",
#           "2017-09",
#           "2017-10",
#           "2017-11"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-02",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-03",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-04",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-05",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-07",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-08",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-09",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-10",
#           "http://data.neonscience.org:80/api/v0/data/DP1.00005.001/SRER/2017-11"
#         ]
#       },
#       {
#         "dataProductCode": "DP1.10086.001",
#         "dataProductTitle": "Soil physical properties (Distributed periodic)",
#         "availableMonths": [
#           "2016-06",
#           "2016-07",
#           "2016-10",
#           "2017-06",
#           "2017-08",
#           "2017-11"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.10086.001/SRER/2016-06",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10086.001/SRER/2016-07",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10086.001/SRER/2016-10",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10086.001/SRER/2017-06",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10086.001/SRER/2017-08",
#           "http://data.neonscience.org:80/api/v0/data/DP1.10086.001/SRER/2017-11"
#         ]
#       },
#       {
#         "dataProductCode": "DP2.30018.001",
#         "dataProductTitle": "Canopy nitrogen - flightline",
#         "availableMonths": [
#           "2017-08"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP2.30018.001/SRER/2017-08"
#         ]
#       },
#       {
#         "dataProductCode": "DP1.30008.001",
#         "dataProductTitle": "Spectrometer orthrorectified at-sensor radiance - flightline",
#         "availableMonths": [
#           "2017-08"
#         ],
#         "availableDataUrls": [
#           "http://data.neonscience.org:80/api/v0/data/DP1.30008.001/SRER/2017-08"
#         ]
#       }
#     ],
#     "siteName": "Santa Rita Experimental Range Site, CORE"
#   }
# }

# %% [markdown]
# We subset the data to look for the discrete lidar data by date using the product code:

# %%
data_products = site_response_json['data']['dataProducts']

#use a list comprehension here if you're feeling fancy
for data_product in data_products:
    if (data_product['dataProductCode'] == PRODUCTCODE):
        months = data_product['availableMonths']

print(months)
# Out:
# ['2017-08']

# %% [markdown]
# Using the result we select the date range for only these lidar data:

# %%
data_response = requests.get(SERVER + 'data/' + PRODUCTCODE + '/' + SITECODE + '/' + '2017-08')
data_response_json = data_response.json()
print(json.dumps(data_response_json, indent=2))
# Out:
# {
#   "data": {
#     "files": [
#       {
#         "crc32": "f66620a2",
#         "name": "NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz",
#         "size": "5419228",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=f24b5d39cc1c13a2c974b5a4bee8e97ddf0ed2d1f07e300abbe6ae9b076b7db8"
#       },
#       {
#         "crc32": "647c4903",
#         "name": "NEON_D14_SRER_DP1_519000_3522000_classified_point_cloud.laz",
#         "size": "9723890",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_519000_3522000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=b079dd7696814dd38d1c52ea86e99379efd22fff9d411f5d9f8504219b8fc5f3"
#       },
#       {
#         "crc32": "8cf7e30d",
#         "name": "NEON_D14_SRER_DP1_L087-1_2017082516_unclassified_point_cloud.laz",
#         "size": "40501643",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_L087-1_2017082516_unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=b3dfe82a6f151017070f4b2b29c119d04944ab89c6c12b279941fb6e6e4d8e42"
#       },
#       {
#         "crc32": "59f759f8",
#         "name": "NEON_D14_SRER_DP1_L031-1_2017082419_unclassified_point_cloud.laz",
#         "size": "29146482",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_L031-1_2017082419_unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=12ddb29a6ad48ae469c1544eecbbc8e5ce75a600b6c3dd7d5499d5c9ec0348b2"
#       },
#       {
#         "crc32": "303e53c4",
#         "name": "NEON_D14_SRER_DP1_L065-2_2017082519_unclassified_point_cloud.laz",
#         "size": "18820462",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_L065-2_2017082519_unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=16f1ea7771bde6c24122737f8ff92c8fc5efa6786205539a17551554ef4681a9"
#       },
#       {
#         "crc32": "2deb042c",
#         "name": "NEON_D14_SRER_DP1_516000_3515000_classified_point_cloud.laz",
#         "size": "9326370",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_516000_3515000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=aba210fffed00fd9d0556c9c3be833ddc3f74c97da4f53dbb7ea1b38c7ea8a50"
#       },
#       {
#         "crc32": "6146d0cc",
#         "name": "NEON_D14_SRER_DP1_518000_3513000_classified_point_cloud.laz",
#         "size": "13832171",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_518000_3513000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=9b8ff7e424dfaaee11a2f97f47dae6d830880b880374f153c46261732782a234"
#       },
#       {
#         "crc32": "f9fdbf73",
#         "name": "NEON_D14_SRER_DP1_522000_3517000_classified_point_cloud.laz",
#         "size": "3611320",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_522000_3517000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=a77fdaa9ea16766b22c3f7c705e74dd9dffbc0bf8f422ed83dc65c0eb2cbedce"
#       },
#       {
#         "crc32": "4e235ef7",
#         "name": "NEON_D14_SRER_DP1_512000_3518000_classified_point_cloud.laz",
#         "size": "10537976",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_512000_3518000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=291e45e2a35c9f5be69ad42cbc4db5b2737d8425a8bf5955d3c360262b24092a"
#       },
#       {
#         "crc32": "d1a91b00",
#         "name": "NEON_D14_SRER_DP1_507000_3523000_classified_point_cloud.laz",
#         "size": "10151645",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_507000_3523000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=80de04a75878dbc3255de8afbc08acef1ca6768e2a54ae75eeb6fcef14a166ab"
#       },
#       {
#         "crc32": "15bd9544",
#         "name": "NEON_D14_SRER_DP1_L085-3_2017082519_unclassified_point_cloud.laz",
#         "size": "2385804",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_
_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=34b8c23a44f2a3543cca3bbb903ba47a7f7f8c38144f646f626c454a73d6ec1a"
#       },
#       {
#         "crc32": "6f274bba",
#         "name": "NEON_D14_SRER_DP1_521000_3513000_classified_point_cloud.laz",
#         "size": "9171190",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_521000_3513000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=ceb965cda140bd54970940121e2bcbb35623f5aa2882ad345985dee8e825cdc9"
#       },
#       {
#         "crc32": "89f3b203",
#         "name": "NEON_D14_SRER_DP1_509000_3524000_classified_point_cloud.laz",
#         "size": "10755463",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_509000_3524000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=c46363b13eaf8b936a90d510cad6fa98cb4c63adbfa42e588fb2166edc66eb87"
#       },
#       {
#         "crc32": "6f504457",
#         "name": "NEON_D14_SRER_DP1_524000_3517000_classified_point_cloud.laz",
#         "size": "2940847",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_524000_3517000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=ba448049ecce48aaaf39ac14cf9a4e14ac618b8e9123b0d1b270e1b65f15c8ed"
#       },
#       {
#         "crc32": "455bad95",
#         "name": "NEON_D14_SRER_DP1_509000_3511000_classified_point_cloud.laz",
#         "size": "5370298",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_509000_3511000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=1b4b913bcb7b1a7cf1f6539dbfc34397825f90e5a1052c32475d2368da637865"
#       },
#       {
#         "crc32": "2b9d7e01",
#         "name": "NEON_D14_SRER_DP1_517000_3511000_classified_point_cloud.laz",
#         "size": "11969164",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_517000_3511000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=2efe44b6fcafe96b593a5a660eb0f5284800b764730dd3b085faaf2eed51330f"
#       },
#       {
#         "crc32": "a3888ed8",
#         "name": "NEON_D14_SRER_DP1_L085-7_2017082913_unclassified_point_cloud.laz",
#         "size": "962728",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_L085-7_2017082913_unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=88d52d55de017a91dce06658d2c9d12a2d23bd276943afe51c032ec83ffb00a8"
#       },
#       {
#         "crc32": "37eef30b",
#         "name": "NEON_D14_SRER_DP1_L088-5_2017082913_unclassified_point_cloud.laz",
#         "size": "25865750",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_L088-5_2017082913_unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=ac726654c3be54a2a30f32a4748aa16587b2ef419a76d94e5cb224750a311fea"
#       },
#       {
#         "crc32": "300990c5",
#         "name": "NEON_D14_SRER_DP1_L088-9_2017082913_unclassified_point_cloud.laz",
#         "size": "1221468",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_L088-9_2017082913_unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=f376dfe004649c27271000269fa32edd4e76abbadb7d7c7c70e0fa3ae97d7a01"
#       },
#       {
#         "crc32": "745f8b6e",
#         "name": "NEON_D14_SRER_DP1_L084-5_2017082913_unclassified_point_cloud.laz",
#         "size": "2367163",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_L084-5_2017082913_unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=0b48a916c8a71ee62143ad91c8e4be5b91d5252a115f7c6afe4f211e6c08a975"
#       },
#       {
#         "crc32": "8f09fd10",
#         "name": "NEON_D14_SRER_DP1_519000_3531000_classified_point_cloud.laz",
#         "size": "7680386",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_519000_3531000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=52cf2c03a777eb940f855b04463ac472b622b54f37ab17ddc3f1f554adb69e5d"
#       },
#       {
#         "crc32": "e0960e3a",
#         "name": "NEON_D14_SRER_DP1_511000_3513000_classified_point_cloud.laz",
#         "size": "10770502",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_511000_3513000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=7976917da248d5a0f01af5b7922d3ed01c08bdbb20700fa97563e401adff53d8"
#       },
#       {
#         "crc32": "be4f1a15",
#         "name": "NEON_D14_SRER_DP1_519000_3521000_classified_point_cloud.laz",
#         "size": "11299007",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1
unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184557Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=3f6d470d8d56e6c66ddace3a1faee863cbc7c2af7a004a8f8156dcc4bea848fe"
#       },
#       {
#         "crc32": "8356d20b",
#         "name": "NEON_D14_SRER_DP1_L079-1_2017082519_unclassified_point_cloud.laz",
#         "size": "53246295",
#         "url": "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/Laz/NEON_D14_SRER_DP1_L079-1_2017082519_unclassified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184557Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=46c0ae5b157fe59bcc3f2e28b3723db21bb4875d67cbef201ff9a10318bda1bc"
#       }
#     ],
#     "productCode": "DP1.30003.001",
#     "siteCode": "SRER",
#     "month": "2017-08"
#   }
# }

# %% [markdown]
# We can see how many files are in the dataset:

# %%
print("number of files in dataset: ")
number_files = print(len(data_response_json["data"]["files"][0]["url"]))
# Out:
# number of files in dataset:
# 444

# %% [markdown]
# The JSON blob returns with the name of the tiles and their url for downloading.
#
# We can go a level deeper into the JSON by looking for the individual file url, name, and size:

# %%
data_url = data_response_json["data"]["files"][0]["url"]
data_name = data_response_json["data"]["files"][0]["name"]
data_size = data_response_json["data"]["files"][0]["size"]
print(json.dumps(data_url, indent=0))
print(json.dumps(data_name, indent=0))
print(json.dumps(data_size, indent=0))
# Out:
# "https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=f24b5d39cc1c13a2c974b5a4bee8e97ddf0ed2d1f07e300abbe6ae9b076b7db8"
# "NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz"
# "5419228"

# %%
print(data_url)
# Out:
# https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184556Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=f24b5d39cc1c13a2c974b5a4bee8e97ddf0ed2d1f07e300abbe6ae9b076b7db8

# %%
path = '/home/tswetnam/Downloads/' + data_name
print(path)
# Out:
# ~/Downloads/NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz

# %%
data_response = requests.get(SERVER + 'data/' + PRODUCTCODE + '/' + SITECODE + '/' + '2017-08')
data_response_json = data_response.json()
data_url = data_response_json["data"]["files"][0]["url"] 
print("Data URL: " + data_url)
data_name = data_response_json["data"]["files"][0]["name"]
data_size = data_response_json["data"]["files"][0]["size"]
path = '/home/tswetnam/Downloads/' + data_name
# Out:
# Data URL: https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180410T184816Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=pub-internal-read%2F20180410%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=e0c8621c55c9779f8fdba33b3b487fe7b40b7e1b47adfb798f4721725ec8937b

# %%
extension_filename = data_url.split('/')[-1]
local_filename = extension_filename.split('?')[-2]
print(local_filename)
# Out:
# NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz

# %% [markdown]
# We are ready to download individual files using the GET command:

# %%
print("Downloading file of size " + data_size + " to " + path)
response = requests.get(data_url, stream=True)  
handle = open(path, "wb")
start_time = time.time()
for chunk in response.iter_content(chunk_size=67108864):
    if chunk: # filter out to keep alive new chunks
        handle.write(chunk)
        print("Downloaded size: " + file_size(path))
    print("Expected file size: " + data_size + " bytes")
    print("Downloaded file size: " + file_size(path))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Downloading file of size 5419228 to /home/tswetnam/Downloads/NEON_D14_SRER_DP1_507000_3515000_classified_point_cloud.laz
# Downloaded size: 5.2 MB
# Expected file size: 5419228 bytes
# Downloaded file size: 5.2 MB
# --- 7.8473591804504395 seconds ---

# %% [markdown]
# I've written a for loop to query the server for the JSON every time a new file is requested.
#
# Initially,  I had a problem with the loop timing out from the initial requests.get  because
#
# the NEON API creates a time stamp for when you hit the service, after about 5 minutes the files
#
# were breaking and only the headers were being downloaded.

# %%
for x in range(0, 443):
    data_response = requests.get(SERVER + 'data/' + PRODUCTCODE + '/' + SITECODE + '/' + '2017-08')
    data_response_json = data_response.json()
    data_url = data_response_json["data"]["files"][x]["url"] 
    print("Data URL: " + data_url)
    data_name = data_response_json["data"]["files"][x]["name"]
    data_size = data_response_json["data"]["files"][x]["size"]
    path = '/vol_c/srer/' + data_name
    print("Downloading file of size " + data_size + " to " + path)
    response = requests.get(data_url)  
    handle = open(path, "wb")
    for chunk in response.iter_content(chunk_size=67108864):
        if chunk: # filter out to keep alive new chunks
            handle.write(chunk)
    print(data_name + " downloaded!")
    print("Expected file size: " + data_size)
    print("Downloaded file size: " + file_size(path))
# Out:
# Data URL: https://neon-aop-product.s3.data.neonscience.org:443/2017/FullSite/D14/2017_SRER_1/L1/DiscreteLidar/ClassifiedPointCloud/NEON_D14_SRER_DP1_518000_3516000_classified_point_cloud.laz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20180409T221350Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=pub-internal-read%2F20180409%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Signature=597911c1bba45e26adfd048c67688a3f59716a3a5838c5c235820cc312cd988c
# Downloading file of size 15645597 to /vol_c/srer/NEON_D14_SRER_DP1_518000_3516000_classified_point_cloud.laz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-fd06c8e40e38> in <module>()
#       8     path = '/vol_c/srer/' + data_name
#       9     print("Downloading file of size " + data_size + " to " + path)
# ---> 10     response = requests.get(data_url)
#      11     handle = open(path, "wb")
#      12     for chunk in response.iter_content(chunk_size=67108864):
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     656
#     657         if not stream:
# --> 658             r.content
#     659
#     660         return r
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in content(self)
#     821                 self._content = None
#     822             else:
# --> 823                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     824
#     825         self._content_consumed = True
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     434         else:
#     435             while not is_fp_closed(self._fp):
# --> 436                 data = self.read(amt=amt, decode_content=decode_content)
#     437
#     438                 if data:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~/anaconda3/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~/anaconda3/lib/python3.6/http/client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %% [markdown]
# Once the data are done downloading to my VM, I'm ready  to move onto the next step, filtering and processing the data with PDAL
